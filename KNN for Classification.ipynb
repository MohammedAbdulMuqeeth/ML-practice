# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cancer = pd.read_csv('d:/dataset/cancerdata.csv')

# %%
X = cancer.drop(['id','diagnosis','Unnamed: 32'],axis=1)

# %%
cancer.drop(['id','Unnamed: 32'],axis=1, inplace=True)

# %%
cancer.head()
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M        17.99         10.38          122.80     1001.0
# 1         M        20.57         17.77          132.90     1326.0
# 2         M        19.69         21.25          130.00     1203.0
# 3         M        11.42         20.38           77.58      386.1
# 4         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
# Scaling the features
from sklearn.preprocessing import StandardScaler

Scaler = StandardScaler()
Scaler.fit(cancer.drop('diagnosis',axis=1))
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
Scaled_features = Scaler.transform(cancer.drop('diagnosis',axis=1))

# %%
Scaled_features
# Out:
# array([[ 1.09706398, -2.07333501,  1.26993369, ...,  2.29607613,
#          2.75062224,  1.93701461],
#        [ 1.82982061, -0.35363241,  1.68595471, ...,  1.0870843 ,
#         -0.24388967,  0.28118999],
#        [ 1.57988811,  0.45618695,  1.56650313, ...,  1.95500035,
#          1.152255  ,  0.20139121],
#        ...,
#        [ 0.70228425,  2.0455738 ,  0.67267578, ...,  0.41406869,
#         -1.10454895, -0.31840916],
#        [ 1.83834103,  2.33645719,  1.98252415, ...,  2.28998549,
#          1.91908301,  2.21963528],
#        [-1.80840125,  1.22179204, -1.81438851, ..., -1.74506282,
#         -0.04813821, -0.75120669]])

# %%
# Dataframe based on the scaled features

# %%
cancer.head()
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M        17.99         10.38          122.80     1001.0
# 1         M        20.57         17.77          132.90     1326.0
# 2         M        19.69         21.25          130.00     1203.0
# 3         M        11.42         20.38           77.58      386.1
# 4         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
cancer.columns
# Out:
# Index(['diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %%
cancer.columns[1:]
# Out:
# Index(['radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean',
#        'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %%
df_feat = pd.DataFrame(Scaled_features,columns=cancer.columns[1:])

# %%
df_feat
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0       1.097064     -2.073335        1.269934   0.984375         1.568466
# 1       1.829821     -0.353632        1.685955   1.908708        -0.826962
# 2       1.579888      0.456187        1.566503   1.558884         0.942210
# 3      -0.768909      0.253732       -0.592687  -0.764464         3.283553
# 4       1.750297     -1.151816        1.776573   1.826229         0.280372
# ..           ...           ...             ...        ...              ...
# 564     2.110995      0.721473        2.060786   2.343856         1.041842
# 565     1.704854      2.085134        1.615931   1.723842         0.102458
# 566     0.702284      2.045574        0.672676   0.577953        -0.840484
# 567     1.838341      2.336457        1.982524   1.735218         1.525767
# 568    -1.808401      1.221792       -1.814389  -1.347789        -3.112085
#
# ...

# %%
X = df_feat
y = cancer['diagnosis']

# %%
y
# Out:
# 0      M
# 1      M
# 2      M
# 3      M
# 4      M
#       ..
# 564    M
# 565    M
# 566    M
# 567    M
# 568    B
# Name: diagnosis, Length: 569, dtype: object

# %%
#Split the data
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=.25)

# %%
# Build the KNN  Classifier  -- Model

from sklearn.neighbors import KNeighborsClassifier

# Initialize the Model

cancer_predit = KNeighborsClassifier(n_neighbors=40)     # k =

# %%
# Train / fit the model
cancer_predit.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=40, p=2,
#                      weights='uniform')

# %%
# Score
print (cancer_predit.score(X_test,y_test))
# Out:
# 0.9440559440559441

# %%
prediction = cancer_predit.predict(X_test)

# %%
# classification report & conf. matrix

from sklearn.metrics import classification_report
print (classification_report(y_test,prediction))
# Out:
#               precision    recall  f1-score   support
#
#            B       0.93      0.99      0.96        93
#            M       0.98      0.86      0.91        50
#
#     accuracy                           0.94       143
#    macro avg       0.95      0.92      0.94       143
# weighted avg       0.95      0.94      0.94       143

# %%
#  Elbow method 
error_rate = []
for i in range(1,40):
    cancer_predit2 = KNeighborsClassifier(n_neighbors=i)
    cancer_predit2.fit(X_train,y_train)
    pred = cancer_predit2.predict(X_test)
    error_rate.append(np.mean(pred != y_test))

# %%
error_rate
# Out:
# [0.04895104895104895,
#  0.04895104895104895,
#  0.03496503496503497,
#  0.04195804195804196,
#  0.03496503496503497,
#  0.03496503496503497,
#  0.027972027972027972,
#  0.04195804195804196,
#  0.04195804195804196,
#  0.04895104895104895,
#  0.04895104895104895,
#  0.04895104895104895,
#  0.04895104895104895,
#  0.055944055944055944,
#  0.055944055944055944,
#  0.04195804195804196,
#  0.04895104895104895,
#  0.04195804195804196,
#  0.04195804195804196,
#  0.04895104895104895,
#  0.055944055944055944,
#  0.055944055944055944,
#  0.055944055944055944,
#  0.055944055944055944,
#  0.055944055944055944,
#  0.055944055944055944,
#  0.055944055944055944,
#  0.04895104895104895,
#  0.055944055944055944,
#  0.055944055944055944,
#  0.055944055944055944,
#  0.055944055944055944,
#  0.055944055944055944,
#  0.04895104895104895,
#  0.055944055944055944,
#  0.04895104895104895,
#  0.055944055944055944,
#  0.055944055944055944,
#  0.06293706293706294]

# %%
# plot

plt.figure(figsize=(10,6))
plt.plot(range(1,40),error_rate,color='blue',linestyle='dashed',
                marker='o',markerfacecolor='red',markersize=10)
plt.title('Error rate vs K value')
plt.xlabel('K')
plt.ylabel('Error rate')

plt.show()
